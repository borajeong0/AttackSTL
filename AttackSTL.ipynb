# %%
from AttackSTL import *
from dataload import *

Dataset = get_dataset(root_dir = 'your directory', batch_size = 128)
Device = torch.device('cuda:0') if torch.cuda.is_available() else 'cpu'

for a in range(1,5):
    real(a, tg='STL_C', device=Device, dataset=Dataset)
    real(a, tg='STL_L', device=Device, dataset=Dataset)
    
for n in range(1,5):
    binary(n, tg='STL_C', device=Device, dataset=Dataset)
    binary(n, tg='STL_L', device=Device, dataset=Dataset)
